# %% [markdown]
# Fetching the data from the URL:  https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data
# It's from UCI repository.

# %%
import pandas as pd

#reading the data

path="https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data"

data = pd.read_csv(path,header=None)
data
# Out:
#      0    1            2       3      4     5            6    7      8   \
# 0     3    ?  alfa-romero     gas    std   two  convertible  rwd  front
# 1     3    ?  alfa-romero     gas    std   two  convertible  rwd  front
# 2     1    ?  alfa-romero     gas    std   two    hatchback  rwd  front
# 3     2  164         audi     gas    std  four        sedan  fwd  front
# 4     2  164         audi     gas    std  four        sedan  4wd  front
# 5     2    ?         audi     gas    std   two        sedan  fwd  front
# 6     1  158         audi     gas    std  four        sedan  fwd  front
# 7     1    ?         audi     gas    std  four        wagon  fwd  front
# 8     1  158         audi     gas  turbo  four        sedan  fwd  front
# 9     0    ?         audi     gas  turbo   two    hatchback  4wd  front
# 10    2  192          bmw     gas    std   two        sedan  rwd  front
# 11    0  192          bmw     gas    std  four        sedan  rwd  front
# ...

# %% [markdown]
# Currently, there is no header_type, the pandas made an automatic header with integer values.
# Hence providing the column names to the dataset for making futher processing to handle easier.

# %%
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
headers
# Out:
# ['symboling',
#  'normalized-losses',
#  'make',
#  'fuel-type',
#  'aspiration',
#  'num-of-doors',
#  'body-style',
#  'drive-wheels',
#  'engine-location',
#  'wheel-base',
#  'length',
#  'width',
#  'height',
#  'curb-weight',
#  'engine-type',
#  'num-of-cylinders',
#  'engine-size',
#  'fuel-system',
#  'bore',
#  'stroke',
#  'compression-ratio',
#  'horsepower',
#  'peak-rpm',
#  'city-mpg',
#  'highway-mpg',
#  'price']

# %% [markdown]
# Replaceing these headers in the above dataset, as mentioned above.

# %%
data.columns = headers
#Let's recheck the dataset
data.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1  convertible          rwd           front        88.6  ...            130
# 2    hatchback          rwd           front        94.5  ...            152
# 3        sedan          fwd           front        99.8  ...            109
# 4        sedan          4wd           front        99.4  ...            136
#
# ...

# %% [markdown]
# let's read the statistics and info about the dataset

# %%
data.describe(include = 'all')

# 'NaN' means not a number
# Out:
#          symboling normalized-losses    make fuel-type aspiration  \
# count   205.000000               205     205       205        205
# unique         NaN                52      22         2          2
# top            NaN                 ?  toyota       gas        std
# freq           NaN                41      32       185        168
# mean      0.834146               NaN     NaN       NaN        NaN
# std       1.245307               NaN     NaN       NaN        NaN
# min      -2.000000               NaN     NaN       NaN        NaN
# 25%       0.000000               NaN     NaN       NaN        NaN
# 50%       1.000000               NaN     NaN       NaN        NaN
# 75%       2.000000               NaN     NaN       NaN        NaN
# max       3.000000               NaN     NaN       NaN        NaN
#
#        num-of-doors body-style drive-wheels engine-location  wheel-base  ...   \
# count           205        205          205             205  205.000000  ...
# ...

# %%
#Checking the datatypes present in the dataset
data.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %% [markdown]
# Save the dataset into csv file by running these commands-
# 1. path = "Enter your path here"
# 2. data.to_csv(path)

# %% [markdown]
# Now, let's see data wrangling. Data Wrangling is the process of converting data from the initial format to a format that may be better for analysis.

# %%
#current data looks like this
data.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1  convertible          rwd           front        88.6  ...            130
# 2    hatchback          rwd           front        94.5  ...            152
# 3        sedan          fwd           front        99.8  ...            109
# 4        sedan          4wd           front        99.4  ...            136
#
# ...

# %% [markdown]
# Replacing '?' with 'Nan'.

# %%
import numpy as np

data.replace("?", np.nan, inplace = True)
data.head(5)
#data changed
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1  convertible          rwd           front        88.6  ...            130
# 2    hatchback          rwd           front        94.5  ...            152
# 3        sedan          fwd           front        99.8  ...            109
# 4        sedan          4wd           front        99.4  ...            136
#
# ...

# %% [markdown]
# Evaluating the missing values in the dataset

# %%
#shows all missing values with counting the values in each column
data.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %% [markdown]
# ## Data Cleaning: Processing the missing data
# Drop or replace are two options.
# Replace by frequency or replace by mean or any other function. Drop the whole row or column.

# %%
#Calculate the average of column
mean_col_normalized_losses = data["normalized-losses"].astype("float").mean(axis = 0)
mean_col_normalized_losses
# Out:
# 122.0

# %%
# Replace the NaN by mean value in "normalized-losses" column
data["normalized-losses"].replace(np.nan, mean_col_normalized_losses, inplace = True)
data["normalized-losses"]
# Out:
# 0      122
# 1      122
# 2      122
# 3      164
# 4      164
# 5      122
# 6      158
# 7      122
# 8      158
# 9      122
# 10     192
# 11     192
# 12     188
# 13     188
# 14     122
# 15     122
# 16     122
# 17     122
# 18     121
# 19      98
# 20      81
# 21     118
# 22     118
# 23     118
# 24     148
# 25     148
# 26     148
# 27     148
# 28     110
# 29     145
#       ...
# 175     65
# 176     65
# 177     65
# 178    197
# 179    197
# 180     90
# 181    122
# 182    122
# 183    122
# 184     94
# 185     94
# 186     94
# 187     94
# 188     94
# 189    122
# 190    256
# 191    122
# 192    122
# 193    122
# 194    103
# 195     74
# 196    103
# 197     74
# 198    103
# 199     74
# 200     95
# 201     95
# 202     95
# 203     95
# 204     95
# Name: normalized-losses, Length: 205, dtype: object

# %% [markdown]
# Repeat the same calculations for 'bore', 'stroke', 'horsepower', 'peak-rpm'.

# %%
mean_bore = data['bore'].astype('float').mean(axis=0)
data['bore'].replace(np.nan, mean_bore, inplace= True)

mean_bore = data['stroke'].astype('float').mean(axis=0)
data['stroke'].replace(np.nan, mean_bore, inplace= True)

mean_horsepower = data['horsepower'].astype('float').mean(axis=0)
data['horsepower'].replace(np.nan, mean_horsepower, inplace= True)

mean_peak_rpm = data['peak-rpm'].astype('float').mean(axis=0)
data['peak-rpm'].replace(np.nan, mean_peak_rpm, inplace= True)

# %% [markdown]
# Another column is 'num-of-doors'. The data element is four or two. Hence check the statistics of the data set.
# And replace the missing values by the element having maximum frequency.

# %%
# check the frequency of all the data elements in the column.
data['num-of-doors'].value_counts()

#                      OR

# Directly see the maximum frequency element.
data['num-of-doors'].value_counts().idxmax()
print("Maximum occurred element is: ",data['num-of-doors'].value_counts().idxmax())

#replace by four, four is having the maximum frequency.
data["num-of-doors"].replace(np.nan, "four", inplace = True)
data["num-of-doors"]
# Out:
# Maximum occurred element is:  four
# 0       two
# 1       two
# 2       two
# 3      four
# 4      four
# 5       two
# 6      four
# 7      four
# 8      four
# 9       two
# 10      two
# 11     four
# 12      two
# 13     four
# 14     four
# 15     four
# 16      two
# 17     four
# 18      two
# 19      two
# 20     four
# 21      two
# 22      two
# 23      two
# 24     four
# 25     four
# 26     four
# 27     four
# 28     four
# 29      two
#        ...
# 175    four
# 176    four
# 177    four
# 178     two
# 179     two
# 180    four
# 181    four
# 182     two
# 183     two
# 184    four
# 185    four
# 186    four
# 187    four
# 188    four
# 189     two
# 190     two
# 191    four
# 192    four
# 193    four
# 194    four
# 195    four
# 196    four
# 197    four
# 198    four
# 199    four
# 200    four
# 201    four
# 202    four
# 203    four
# 204    four
# Name: num-of-doors, Length: 205, dtype: object

# %% [markdown]
# Now, see the dataset again. Check the 'price' column and the number of null values inside it.
# Since it is very small, hence drop all the values from the rows having empty dataset. Instead you can follow other methods described above. Just for practice, dropping the entrire row. Also reset the index afterwards.

# %%
data['price'].isnull().sum()
#print('The number of missing values are: ',data['price'].isnull().sum())
print("\n")
# Drop the row with Nan value.
data.dropna(subset=["price"], axis=0, inplace = True)
data['price']

# Reset the index
data.reset_index(drop = True, inplace = True)

# Check the dataset
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               122  alfa-romero       gas        std          two
# 1          3               122  alfa-romero       gas        std          two
# 2          1               122  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1  convertible          rwd           front        88.6  ...            130
# 2    hatchback          rwd           front        94.5  ...            152
# 3        sedan          fwd           front        99.8  ...            109
# 4        sedan          4wd           front        99.4  ...            136
#
# ...

# %% [markdown]
# ## Working on data format

# %%
#Check all the datatpes

data.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %% [markdown]
# The data column 'normalized-losses', 'price', 'peak-rpm' ,'bore' and 'stroke' variables are numerical values, but it is showing as object type. It should be in float or int type format.

# %%
data[["bore", "stroke"]] = data[["bore", "stroke"]].astype("float")
data[["normalized-losses"]] = data[["normalized-losses"]].astype("int")
data[["price"]] = data[["price"]].astype("float")
data[["peak-rpm"]] = data[["peak-rpm"]].astype("float")

#check the column type again
data.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower            object
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %% [markdown]
# ## Data Standarization
#
# This is the process to transform the data into meaningful comparisons.
# Here we will transform the mpg to L/100 km interms of fuel consumption in the dataset. The formula for unit conversion is L/100km = 235 / mpg.

# %%
# transform mpg to L/100km 
data['city-L/100km'] = 235/data["city-mpg"]
#data['city-L/100km']

#similarly 
data['highway-L/100km'] = 235/data["highway-mpg"]
#data['highway-L/100km']


#Renaming the column names
data.rename(columns={'"highway-mpg"':'highway-L/100km'}, inplace=True)
data.rename(columns={'"city-mpg"':'city-L/100km'}, inplace=True)

# %% [markdown]
# ## Data Normalisation
# Normalization is the process of transforming values of several variables into a similar range. Scaling includes the variable average is 0, scaling the variable so the variable variance is 1, or scaling variable so the variable values range from 0 to 1. Here,  I'm normalizing "length", "width" and "height" in the range of [0,1].

# %%
# replace (origianl value) by (original value)/(maximum value)
data['length'] = data['length']/data['length'].max()
data['width'] = data['width']/data['width'].max()
#data['length']
data['height'] = data['height']/data['height'].max()

# %% [markdown]
# ## Binning
# Binning is a process of transforming continuous numerical variables into discrete categorical 'bins', for grouped analysis.
#  "horsepower" is a real valued variable ranging from 48 to 288, with different values. Tranforming the elements into high, medium and low as per the prices.

# %%
data["horsepower"]=data["horsepower"].astype(float, copy=True)

#bin_size = 4
binwidth = (max(data["horsepower"])-min(data["horsepower"]))/4

bins = np.arange(min(data["horsepower"]), max(data["horsepower"]), binwidth)
print(bins)

#group name
group_names = ['Low', 'Medium', 'High']

data['horsepower-binned'] = pd.cut(data['horsepower'], bins, labels=group_names,include_lowest=True )
data[['horsepower','horsepower-binned']].head(20)
# Out:
# [ 48.  101.5 155.  208.5]
#     horsepower horsepower-binned
# 0        111.0            Medium
# 1        111.0            Medium
# 2        154.0            Medium
# 3        102.0            Medium
# 4        115.0            Medium
# 5        110.0            Medium
# 6        110.0            Medium
# 7        110.0            Medium
# 8        140.0            Medium
# 9        101.0               Low
# 10       101.0               Low
# 11       121.0            Medium
# 12       121.0            Medium
# 13       121.0            Medium
# 14       182.0              High
# 15       182.0              High
# 16       182.0              High
# 17        48.0               Low
# 18        70.0               Low
# 19        70.0               Low

# %% [markdown]
# ## Bins visualization
#
# Using matplotlib

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot

a = (0,1,2)

# draw historgram of attribute "horsepower" with bins = 3
plt.pyplot.hist(data["horsepower"], bins = 3)

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %% [markdown]
# ##One hot encoding
#
# When there is a categorical data and the data is unable to get inferences, then one hot enoding can be precessed to make the algorithms to adapt and predict. In pandas, it can be done via providing dummies.

# %%
dummy_variable_1 = pd.get_dummies(data["fuel-type"])
print(dummy_variable_1.head())

#changeing the name of the columns
dummy_variable_1.rename(columns={'fuel-type-diesel':'gas', 'fuel-type-diesel':'diesel'}, inplace=True)
dummy_variable_1.head()
# Out:
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %% [markdown]
# Above the diesel is 0 and the gas is 1.
# Now merging the one hot encoding into the original data.

# %%
# merge data frame "data" and "dummy_variable_1" 
data = pd.concat([data, dummy_variable_1], axis=1)

# drop original column "fuel-type" from "data"
data.drop("fuel-type", axis = 1, inplace=True)

# %% [markdown]
# # Concluding good Predictor variables for the target
#
#
# ##Grouping data
#
# This will allow you to analyze data with respect to the particular column, i.e., body-style, drive-wheels can used as a feaute to analyze the price. 'groupby' method can make you understand more about the these particular data columns.

# %%
data.head(5)
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length ...   \
# 0  convertible          rwd           front        88.6  0.811148 ...
# 1  convertible          rwd           front        88.6  0.811148 ...
# 2    hatchback          rwd           front        94.5  0.822681 ...
# 3        sedan          fwd           front        99.8  0.848630 ...
# 4        sedan          4wd           front        99.4  0.848630 ...
#
#    horsepower  peak-rpm  city-mpg highway-mpg    price  city-L/100km  \
# ...

# %%
data_groupby = data[['drive-wheels','body-style', 'price']]
#print(data_groupby)                     
data_group = data_groupby.groupby(['drive-wheels','body-style'], as_index = False).mean()
data_group
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %% [markdown]
# Average price for each wheel drive with their particular body style is provided above.
# ##Pivot()
# Pivot can be used to display the variable along the columns and other variables displayed along rows to study the data.

# %%
data_pivot = data_group.pivot(index = 'drive-wheels', columns = 'body-style')
data_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %% [markdown]
# ##Relationship between variables
#
# ##Correlation
#
# Correlation tells how the variables are related or depending on each other.
# 1. Positive Correlation: both variables change in the same direction.
# 2. Neutral Correlation: No relationship in the change of the variables.
# 3. Negative Correlation: variables change in opposite directions.
#
# Explanation:
# 1. Positive correlation means that they depending each other in same direction. Ex:  6 seater SUV have higher price from 4 seater (if they belongs to same manufacturing company***), i.e., number of seats increasing means price is increasing.
# 2. Negative correlation means, again the data is depending but in opposite direction, i.e., if one variable is decreasig then other is increasing.
# 3. Neutral correlation means, no relationship between variables.
#
# Types of correlation is :
# 1. Covariance
# 2. Pearson's correlation- returns a value between -1 and 1. Notable correlation is - return is above 0.5 or below -0.5. 0 means no relation.
# 3. Spearman's correlation
#
#
#
# We will use Pearson's correlation here to test.

# %%
# Checking correlations between all variables.
data.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008153           0.055045    0.158018  0.123952
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %% [markdown]
# Deriving the correlation between certain variables in the data set.

# %%
data[['bore','stroke' ,'compression-ratio','horsepower']].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187871    0.098267
# compression-ratio  0.001263  0.187871           1.000000   -0.214514
# horsepower         0.566936  0.098267          -0.214514    1.000000

# %% [markdown]
# ## Extracting Relationships using Visualization
# ##Positive linear relationship
#
# We can see the relationship between variables by visualizing them via a regression line. From the above correlation description we can see that, engine_size have stronger positive relation with price. Let's visualize the relationship.

# %%
data[["engine-size", "price"]].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 


sns.regplot(x="engine-size", y="price", data=data)
plt.ylim(0,)
# Out:
# (0, 55817.30849859861)

# %% [markdown]
# Via visualization, as engine size grows the price also goes up. Hence,  engine size can be take as a  good predictor of price since the regression line is almost a perfect diagonal line. And also the Pearson's correlation value is approximately 0.87.

# %% [markdown]
# ##Negative linear relationship
#
# Now comapring highway-mpg with price.

# %%
data[["highway-mpg", "price"]].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %%
sns.regplot(x="highway-mpg", y="price", data=data)

# %% [markdown]
# As per the given correlation value, i.e., -0.704692. The both values are inversely proportional to each other as per the given visualization, i.e., as highway-mpg is decreasing the price value is increasing. This shows the strong negative realtionship between the variables.
#
#
# ##Weak Linear Relationship

# %%
data[['peak-rpm','price']].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %%
sns.regplot(x="peak-rpm", y="price", data=data)

# %%
data[['stroke','price']].corr()
# Out:
#           stroke     price
# stroke  1.000000  0.082269
# price   0.082269  1.000000

# %%
sns.regplot(x="stroke", y="price", data=data)

# %% [markdown]
# Peak rpm is not a  good predictor of the price. Also, the regression line is horizontal. From the visualization, the  data points are having lots of variability as they are very scattered and far from the fitted line. The correlation value is also -0.1016 approx, which concludes no stronger relation, hence peak-rpm is not a reliable variable for price. Similarly, situation is same with 'stroke' variable.

# %% [markdown]
# ## Visualizing Categorical data
#
# The categorical data describes the characteristics of the data. Bar-plot is the best visualization technique for categorical datas. Body-style, drive-wheels, engine-location are the categorical columns in the data. Let's work on them.

# %%
sns.boxplot(x="body-style", y="price", data=data)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %%
sns.boxplot(x="engine-location", y="price", data=data)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %%
sns.boxplot(x="drive-wheels", y="price", data=data)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %% [markdown]
# ##Descriptive Statistical Analysis
#
# This describes basic features of the data and samples. Also, quantitatively describe the summaries of the data with the help of visualization or simple statistical descriptions.

# %%
# Describes only object datatype variable
data.describe(include=['object'])
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92

# %% [markdown]
# ##Value counts
#
# Value-counts enables to understand the quantitative features of the data. Limitation is, it only works with panda series not with panda dataframes. Hence, data[["column name"]] will not work.

# %%
data['drive-wheels'].value_counts()
# Out:
# fwd    118
# rwd     75
# 4wd      8
# Name: drive-wheels, dtype: int64

# %% [markdown]
# This tells that drive-wheels have 118 types of fwd, 75 times rwd and similar.
# For making the description in the form of data frame, we can apply certain methods.

# %%
drive_wheels_counts = data['drive-wheels'].value_counts().to_frame()
#renaming teh column
drive_wheels_counts.rename(columns={'drive-wheels': 'value_counts'}, inplace=True)
#Renaming the index
drive_wheels_counts.index.name = 'drive-wheels'
drive_wheels_counts
# Out:
#               value_counts
# drive-wheels
# fwd                    118
# rwd                     75
# 4wd                      8

# %%
#similarly other columns
# engine-location as variable
engine_loc_counts = data['engine-location'].value_counts().to_frame()
engine_loc_counts.rename(columns={'engine-location': 'value_counts'}, inplace=True)
engine_loc_counts.index.name = 'engine-location'
engine_loc_counts.head(10)
# Out:
#                  value_counts
# engine-location
# front                     198
# rear                        3

# %% [markdown]
# ##Grouping: Basic
#
# Grouping is the method trying to group other columns. And the analysis can be performed on the basis of single variables.

# %%
data['engine-location'].unique()
# Out:
# array(['front', 'rear'], dtype=object)

# %%
data['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
data['height'].unique()
# Out:
# array([0.81605351, 0.87625418, 0.90802676, 0.88795987, 0.93143813,
#        0.93478261, 0.89799331, 0.94147157, 0.88963211, 0.86956522,
#        0.84949833, 0.84615385, 1.        , 0.83946488, 0.87959866,
#        0.91137124, 0.97491639, 0.89130435, 0.90468227, 0.85284281,
#        0.89464883, 0.85953177, 0.88294314, 0.7993311 , 0.82943144,
#        0.92809365, 0.909699  , 0.94481605, 0.98160535, 0.9180602 ,
#        0.94816054, 0.9264214 , 0.91638796, 0.82608696, 0.86287625,
#        0.91471572, 0.92140468, 0.93812709, 0.83110368, 0.93645485,
#        0.92307692, 0.84448161, 0.87792642, 0.88628763, 0.98829431,
#        0.90133779, 0.92976589, 0.93979933, 0.96153846])

# %% [markdown]
# uniques() gives the information about the types of data elements present in the variable.
#
# ##Pivot
#
# A pivot tableis similar to an Excel spreadsheet, with one variable along the column and another along the row. It is used to convert the dataframe into pivot table as above explained.

# %%
df_gptest=data[['drive-wheels','body-style','price']]
grouped_test1=df_gptest.groupby(['drive-wheels','body-style'],as_index= False).mean()
grouped_test1
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
grouped_pivot=grouped_test1.pivot(index='drive-wheels',columns='body-style')
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %% [markdown]
# If there is any missing values, then it can be filled by-
# grouped_pivot.fillna(0).
#
# ##Heatmap vizualization

# %%
grouped_pivot=grouped_pivot.fillna(0)
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
import matplotlib.pyplot as plt
% matplotlib inline
#use the grouped results
plt.pcolor(grouped_pivot, cmap='RdBu')
plt.colorbar()
plt.show()

# %% [markdown]
# The heatmap plots the target variable (price) proportional to colour with respect to the variables 'drive-wheel' and 'body-style' in the vertical and horizontal axis respectively. The heatmap conclusion is price relation with 'drive-wheel' and 'body-style',
# The default labels convey no useful information to us. Let's change that:

# %%
fig, ax=plt.subplots()
im=ax.pcolor(grouped_pivot, cmap='RdBu')

#label names
row_labels=grouped_pivot.columns.levels[1]
col_labels=grouped_pivot.index
#move ticks and labels to the center
ax.set_xticks(np.arange(grouped_pivot.shape[1])+0.5, minor=False)
ax.set_yticks(np.arange(grouped_pivot.shape[0])+0.5, minor=False)
#insert labels
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)
#rotate label if too long
plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()

# %% [markdown]
# The main question we want to answer in this module, is "What are the main characteristics which have the most impact on the car price?".
#
# To get a better measure of the important characteristics, we look at the correlation of these variables with the car price, in other words: how is the car price dependent on this variable?
#
# reference: https://labs.cognitiveclass.ai/tools/jupyterlab/lab/tree/labs/DA0101EN/https://cocl.us/DA0101EN-Review-Exploratory_Data_Analysis-py-v4pp.ipynb
#
#
# ## Correlation and casuation
#
#  **Correlation**: a measure of the extent of interdependence between variables.
#
# **Causation**: the relationship between cause and effect between two variables.
#
# It is important to know the difference between these two and that correlation does not imply causation. Determining  correlation is much simpler  the determining causation as causation may require independent experimentation.
#
#
#
# Pearson correlation is described above.
#
# **P-value**:
# What is this P-value? The P-value is the probability value that the correlation between these two variables is statistically significant. Normally, we choose a significance level of 0.05, which means that we are 95% confident that the correlation between the variables is significant.
#
# By convention, when the
# - p-value is < 0.001 we say there is strong evidence that the correlation is significant,
# - the p-value is < 0.05; there is moderate evidence that the correlation is significant,
# - the p-value is < 0.1; there is weak evidence that the correlation is significant, and
# - the p-value is > 0.1; there is no evidence that the correlation is significant.
#
# reference: https://labs.cognitiveclass.ai/tools/jupyterlab/lab/tree/labs/DA0101EN/https://cocl.us/DA0101EN-Review-Exploratory_Data_Analysis-py-v4pp.ipynb

# %%
from scipy import stats
pearson_coef, p_value = stats.pearsonr(data['wheel-base'], data['price'])
print("The Pearson Correlation Coefficient is", pearson_coef)
print("P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.5846418222655081
# P-value of P = 8.076488270732955e-20

# %%
pearson_coef, p_value = stats.pearsonr(data['horsepower'], data['price'])
print("The Pearson Correlation Coefficient is", pearson_coef)
print("P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8095745670036559
# P-value of P = 6.36905742825998e-48

# %%
pearson_coef, p_value = stats.pearsonr(data['length'], data['price'])
print("The Pearson Correlation Coefficient is", pearson_coef)
print("P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.6906283804483642
# P-value of P = 8.016477466158713e-30

# %%
pearson_coef, p_value = stats.pearsonr(data['width'], data['price'])
print("The Pearson Correlation Coefficient is", pearson_coef)
print("P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.7512653440522673
# P-value of P = 9.20033551048166e-38

# %%
pearson_coef, p_value = stats.pearsonr(data['curb-weight'], data['price'])
print("The Pearson Correlation Coefficient is", pearson_coef)
print("P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8344145257702846
# P-value of P = 2.1895772388936997e-53

# %%
pearson_coef, p_value = stats.pearsonr(data['engine-size'], data['price'])
print("The Pearson Correlation Coefficient is", pearson_coef)
print("P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8723351674455185
# P-value of P = 9.265491622197996e-64

# %%
pearson_coef, p_value = stats.pearsonr(data['bore'], data['price'])
print("The Pearson Correlation Coefficient is", pearson_coef)
print("P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.5431553832626602
# P-value of P = 8.049189483935364e-17

# %%
pearson_coef, p_value = stats.pearsonr(data['city-mpg'], data['price'])
print("The Pearson Correlation Coefficient is", pearson_coef)
print("P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.6865710067844677
# P-value of P = 2.3211320655676368e-29

# %%
pearson_coef, p_value = stats.pearsonr(data['highway-mpg'], data['price'])
print("The Pearson Correlation Coefficient is", pearson_coef)
print("P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.7046922650589529
# P-value of P = 1.7495471144476807e-31

# %% [markdown]
# The stats is between two variables, this will decide which variables are important for price, i.e., our target.
# ##### Conclusion:
# Since the p-value is < 0.001, the correlation between wheel-base and price is statistically significant, although the linear relationship isn't extremely strong (~0.585) but good enough.
#
#
# ##Anova (Analysis of variables)
#
# A statistical method to test the statistically significant differences between the means of three or more independent (unrelated) groups. Here, the groups are within a one variable. For example, drive-wheels have three groups, i.e., 4wd, fwd, and rwd . There are two parameters in ANOVA to be measured:
#
# **F-test score**: ANOVA assumes the means of all groups are the same, calculates how much the actual means deviate from the assumption, and reports it as the F-test score. A larger score means there is a larger difference between the means.
#
# **P-value**:  P-value tells how statistically significant is our calculated score value
#
# ####Note: If our price variable is strongly correlated with the variable we are analyzing, expect ANOVA to return a sizeable F-test score and a small p-value. Also,  the ANOVA algorithm averages the data automatically, no need to take the average before.

# %%
grouped_test2=df_gptest[['drive-wheels','price']].groupby(['drive-wheels'])
grouped_test2.head(2)
# Out:
#     drive-wheels    price
# 0            rwd  13495.0
# 1            rwd  16500.0
# 3            fwd  13950.0
# 4            4wd  17450.0
# 5            fwd  15250.0
# 136          4wd   7603.0

# %%
grouped_test2.get_group('4wd')['price']
# Out:
# 4      17450.0
# 136     7603.0
# 140     9233.0
# 141    11259.0
# 144     8013.0
# 145    11694.0
# 150     7898.0
# 151     8778.0
# Name: price, dtype: float64

# %%
#ANOVA Algorithm 
from scipy import stats
f_val, p_val = stats.f_oneway(grouped_test2.get_group('fwd')['price'], grouped_test2.get_group('rwd')['price'], grouped_test2.get_group('4wd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 67.95406500780399 , P = 3.3945443577151245e-23

# %% [markdown]
# This is a great result, with a large F test score showing a strong correlation and a P value of almost 0 implying almost certain statistical significance. But does this mean all three tested groups are all this highly correlated? Let's see the results for other groups and variable-

# %%
#separately fwd-rwd

f_val, p_val = stats.f_oneway(grouped_test2.get_group('fwd')['price'], grouped_test2.get_group('rwd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val )
# Out:
# ANOVA results: F= 130.5533160959111 , P = 2.2355306355677845e-23

# %%
#4wd-rwd
f_val, p_val = stats.f_oneway(grouped_test2.get_group('4wd')['price'], grouped_test2.get_group('rwd')['price'])  
   
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 8.580681368924756 , P = 0.004411492211225333

# %%
#4wd-fwd
f_val, p_val = stats.f_oneway(grouped_test2.get_group('4wd')['price'], grouped_test2.get_group('fwd')['price'])  
 
print("ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 0.665465750252303 , P = 0.41620116697845666

# %% [markdown]
# ###In conclusion, the important variables for price is:
#
#
# Continuous numerical variables:
# - Length
# - Width
# - Curb-weight
# - Engine-size
# - Horsepower
# - City-mpg
# - Highway-mpg
# - Wheel-base
# - Bore
#
# Categorical variables:
# - Drive-wheels

# %% [markdown]
# ### Let's see the data again.

# %%
data
# Out:
#      symboling  normalized-losses         make aspiration num-of-doors  \
# 0            3                122  alfa-romero        std          two
# 1            3                122  alfa-romero        std          two
# 2            1                122  alfa-romero        std          two
# 3            2                164         audi        std         four
# 4            2                164         audi        std         four
# 5            2                122         audi        std          two
# 6            1                158         audi        std         four
# 7            1                122         audi        std         four
# 8            1                158         audi      turbo         four
# 9            2                192          bmw        std          two
# 10           0                192          bmw        std         four
# 11           0                188          bmw        std          two
# ...

# %% [markdown]
# Everything looks fit and fine (hope so :).

# %% [markdown]
# # Model Development
#
# Let's predict the price of cars using the data features and variables. This model development will tell the exact relationship b/w the variables and will be used to predict the price.
#
# ## Simple Linear Regression
#
# This is one of the basic model, which is applied on two variables, i.e., dependent and inpendent variable. This model follows linear relation b/w the variables in the form of Y = mX + c, where m is the slope and c is the intercept. (Remember, linear equation of line in coordinate geometry).
#
# We will use the library module name 'sklearn' to create the object of linear regression and will use it for prediction.

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %% [markdown]
# Through ANOVA, practised above, we saw the analysis concludes that highway-mpg is one of the useful variable for predicting price. We will use this as independent variable in the model created to predict the price of the car.
#
# Let's create the dependent and independent variable in model. And then fit the model using these variables.
#
# # Fitting
#
# Fitting of model means, finding suitable values for unknown parameters 'a' and 'b' which will help the variables data to form a relationship of form, Y = b + aX. It's also termed as parameter learning, i.e., trying to find a and b such that the data, matches Y = b + aX as much as possible. Oftenly, this method is known as **TRAINING of data.**

# %%
X = data[['highway-mpg']]
Y = data['price']
lm.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#let's predict the price of car with random value of highway-mpg. (it's just a demo, to show the working of linear regression)
Yhat=lm.predict(X)
Yhat[0:5] #only first five values of highway-mpg
# Out:
# array([16236.50464347, 16236.50464347, 17058.23802179, 13771.3045085 ,
#        20345.17153508])

# %% [markdown]
# Let's check the intercept and slope of the relation.

# %%
lm.intercept_
# Out:
# 38423.3058581574

# %%
lm.coef_
# Out:
# array([-821.73337832])

# %% [markdown]
# Hence, the estimated relationship b/w the two variables of the dataset is :
# **price** = 38423.31 - 821.73 x  **highway-mpg**

# %% [markdown]
# ##Multiple Linear Regression
#
# If we require more than one variable to predict the price, then we use multiple regression. It has the form of :
#  \begin{equation*}
# Y = a + b_1 X_1 + b_2 X_2 + b_3 X_3 + b_4 X_4
# \end{equation*}
#
# Let's build the model for it by above ANOVA analysis.

# %%
independent_variable = data[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]

#Fitting
lm.fit(independent_variable, data['price'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lm.intercept_
# Out:
# 38423.3058581574

# %%
lm.coef_
# Out:
# array([-821.73337832])

# %% [markdown]
# Hence, the predicted model from above is :
# **Price** = -15678.742628061467 + 52.65851272 x **horsepower** + 4.69878948 x **curb-weight** + 81.95906216 x **engine-size** + 33.58258185 x **highway-mpg**

# %% [markdown]
# ##Evaluating Model using Visualization
# Using seaborn library.
# Here for **simple linear regression**, the best visualization for fits is regression plots.
# In regression plot, always see the **scattering of data points**, this will give the insight of variance of data.
#
# highway-mpg vs price
# In this relation the slope of the plot is negative, i.e. price is negative correlated to highway-mpg.

# %%
import seaborn as sns
# %matplotlib inline 

width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="highway-mpg", y="price", data=data)
plt.ylim(0,)
# Out:
# (0, 48275.30374484396)

# %% [markdown]
# Plot b/w peak-rpm vs price.
# In the plot, the data is scattered too much.

# %%
plt.figure(figsize=(width, height))
sns.regplot(x="peak-rpm", y="price", data=data)
plt.ylim(0,)
# Out:
# (0, 47424.38921869223)

# %%
#checking the correlation factor

data[["peak-rpm","highway-mpg","price"]].corr()
# Out:
#              peak-rpm  highway-mpg     price
# peak-rpm     1.000000    -0.058598 -0.101616
# highway-mpg -0.058598     1.000000 -0.704692
# price       -0.101616    -0.704692  1.000000

# %% [markdown]
# Correlation factor is also concluding the same.
#
# Another visualization method is **residual plot**. It shows the difference between observed value and predicted value.
#
# If the points in a residual plot are randomly spread out around the x-axis, then a linear model is appropriate for the data. Why is that? Randomly spread out residuals means that the variance is constant, and thus the linear model is a good fit for this data. (Reference - IBM DA0101EN)

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(data['highway-mpg'], data['price'])
plt.show()

# %% [markdown]
# ##Polynomial Regression
#
# When the non-linear relationships is seen in data by squaring or above degrees is variable, polynomial regression is used.
#
# Ex- From the above model the highway-mpg, do not provide the coorect fit line, then fitting a polynomial model can be processed.

# %%
def PlotPolly(model,independent_variable,dependent_variabble, Name):
    x_new = np.linspace(15, 55, 100)
    y_new = model(x_new)

    plt.plot(independent_variable,dependent_variabble,'.', x_new, y_new, '-')
    plt.title('Polynomial Fit with Matplotlib for Price ~ Length')
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898, 0.898))
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.ylabel('Price of Cars')

    plt.show()
    plt.close()
    
print("done")
# Out:
# done

# %%
x = data['highway-mpg']
y = data['price']


#third order of cubic polynomial
f = np.polyfit(x, y, 3)
p = np.poly1d(f)
print(p)
# Out:
#         3         2
# -1.557 x + 204.8 x - 8965 x + 1.379e+05

# %%
#ploting the data

PlotPolly(p,x,y, 'highway-mpg')
np.polyfit(x, y, 3)
# Out:
# array([-1.55663829e+00,  2.04754306e+02, -8.96543312e+03,  1.37923594e+05])

# %% [markdown]
# ###In Sample Model Evaluation
#
# This is done to tell, how accurate the model is. More specifically, it tells how well the model will fit the data used ot train it. **Be sure**, it will not conclude, how well the trained data can be used to predict the data, in the real world (SOLUTION HINT: spitting the data).
#
# In Statistics the accuracy of a model can be evaluated by:
#
# - **R^2 / R-squared**
# - **Mean Squared Error (MSE)**
#
# **R-squared**
#
# R squared or coefficient of determination, is a measure to indicate how close the data is to the fitted regression line.
# The value of the R-squared is the percentage of variation of the response variable (y) that is explained by a linear model.
#
#
# **Mean Squared Error (MSE)**
#
# The Mean Squared Error measures the average of the squares of errors, that is, the difference between actual value (y) and the estimated value (ŷ).
#
#
# Let's see the evaluation in linear regression model above, between highway-mpg vs price.

# %%
lm.fit(X, Y)
# Find the R^2
lm.score(X, Y)
# Out:
# 0.4965911884339176

# %% [markdown]
# By above calculation, the conclusion is 49.65% of variation in price is calculated by the model.
#
# Let's checl for mean-square error.

# %%
dep_var=lm.predict(X)
dep_var[0:4]
# Out:
# array([16236.50464347, 16236.50464347, 17058.23802179, 13771.3045085 ])

# %%
from sklearn.metrics import mean_squared_error
#mean_squared_error(Y_true, Y_predict)
mean_squared_error(data['price'], dep_var)
# Out:
# 31635042.944639888

# %% [markdown]
# Let's try for multiple regression.

# %%
# fit the model 
lm.fit(independent_variable, data['price'])
# Find the R^2
lm.score(independent_variable, data['price'])
# Out:
# 0.8093562806577457

# %% [markdown]
# That means, 80% of the variance in price is calculated in multiple linear regression.

# %%
depend_predict_multifit = lm.predict(independent_variable)
mean_squared_error(data['price'], depend_predict_multifit)
# Out:
# 11980366.87072649

# %%
##Visualizing the prediction

import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline 

new_input=np.arange(1,100,1).reshape(-1,1)
lm.fit(X, Y)

dep_var=lm.predict(new_input)
dep_var[0:5]

plt.plot(new_input,dep_var)
plt.show()

# %% [markdown]
# ##Decision Making via models
#
# We have calculated the evaluation above for the models. Let's see the decision making in the model.
#
# **What is good R^2 value?**
# The model having higher R^2 value is good model having better fit. In our case multiple regression is the good model that linear regression.
#
# **What is good mean-square value?**
# The model having lower MSE is good model with better fit. In our case, as expected from above result, it's multiple regression.

# %% [markdown]
# From the above section, it's clear that the multiple linear regression is good model. And also if you observe the data, it was having 27 variables, and since it was a common dataset (means most of us is familiar (may be) with auto knowledge), thus it was obvious that we can normally observe there were more tham one variable which are responsible for the car price.

# %% [markdown]
# ##Out-Sample evaluation of the Model
#
# **Spliting of data: train data & test data**
# Important part of model evaluation, training the data only concludes the predictive relationships in the model, and use of testing data evaluates the performance of the model.
#
# ###Generalization error
# This error concludes the performance of data in predicting the unseen data. The error is obtain from testing data is an approximation of this error.
